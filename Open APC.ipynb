# %%
# Pandas-Paket ins Notebook hineinladen
import urllib.request
import pandas as pd

# %%
open_apc_url = "https://raw.githubusercontent.com/OpenAPC/openapc-de/master/data/fuberlin/APC_FU_Berlin_2015.csv"
apc_file = "openapc.csv"

# %%
# Download der Daten
urllib.request.urlretrieve(open_apc_url, apc_file)
# Out:
# ('openapc.csv', <http.client.HTTPMessage at 0x1af7bc255b0>)

# %%
# Data-Frame erstellen
apcs = pd.read_csv(apc_file)

# %%
apc
# Out:
#    institution  period     euro                           doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00         10.1038/npjqi.2015.10      False
# 1    FU Berlin    2015  1503.12     10.1103/PhysRevX.5.041008      False
# 2    FU Berlin    2015  2000.00            10.1038/ncomms9498      False
# 3    FU Berlin    2015  2000.00  10.1371/journal.ppat.1005246      False
# 4    FU Berlin    2015  1805.00     10.1186/s13099-015-0075-z      False
# ..         ...     ...      ...                           ...        ...
# 56   FU Berlin    2015  1731.45     10.1186/s13015-014-0028-y      False
# 57   FU Berlin    2015  1600.00      10.3389/fpsyg.2015.00194      False
# 58   FU Berlin    2015   219.84       10.3389/fevo.2015.00020      False
# 59   FU Berlin    2015  1386.35             10.1038/srep19416      False
# 60   FU Berlin    2015  2000.00           10.1155/2015/569512      False
#
#                            publisher                  journal_full_title  \
# ...

# %%
# Tabelleninfos auslesen (Zeieln, Spalten, etc.) mit Attribut shape
apcs.shape
# Out:
# (61, 17)

# %%
apcs.columns
# Out:
# Index(['institution', 'period', 'euro', 'doi', 'is_hybrid', 'publisher',
#        'journal_full_title', 'issn', 'issn_print', 'issn_electronic',
#        'license_ref', 'indexed_in_crossref', 'pmid', 'pmcid', 'ut', 'url',
#        'doaj'],
#       dtype='object')

# %%
# Dataframe ansprechen: gibt head und tail einer Column aus sowie
# zusätzlich den Namen, die Länge und Datentyp der Spalte
apcs["euro"]
# Out:
# 0     2000.00
# 1     1503.12
# 2     2000.00
# 3     2000.00
# 4     1805.00
#        ...
# 56    1731.45
# 57    1600.00
# 58     219.84
# 59    1386.35
# 60    2000.00
# Name: euro, Length: 61, dtype: float64

# %%
list(apcs["euro"])
# Out:
# [2000.0,
#  1503.12,
#  2000.0,
#  2000.0,
#  1805.0,
#  1191.32,
#  1236.83,
#  1499.08,
#  1160.25,
#  1191.21,
#  1142.4,
#  1298.29,
#  2000.0,
#  1165.0,
#  1386.35,
#  2000.0,
#  892.5,
#  1535.87,
#  223.93,
#  1178.42,
#  1285.52,
#  1392.3,
#  1509.22,
#  2000.0,
#  1249.5,
#  1625.0,
#  1800.0,
#  1550.33,
#  2000.0,
#  2000.0,
#  1429.79,
#  1410.07,
#  2000.0,
#  1785.0,
#  1202.03,
#  1243.27,
#  1687.0,
#  1687.0,
#  895.15,
#  853.84,
#  1904.0,
#  435.46,
#  1150.0,
#  770.0,
#  1299.92,
#  2000.0,
#  1202.03,
#  430.5,
#  1600.0,
#  1280.0,
#  1513.7,
#  1904.0,
#  1072.55,
#  981.75,
#  1969.45,
#  1130.5,
#  1731.45,
#  1600.0,
#  219.84,
#  1386.35,
#  2000.0]

# %%
# Maximalwert aus Spalte Euro abfragen mit Funktion max
apcs["euro"].max()
# Out:
# 2000.0

# %%
# Minimalwert aus Spalte Euro abfragen mit Funktion min
apcs["euro"].min()
# Out:
# 219.84

# %%
# Statistische Werte aus Spalte Euro abfragen mit Funktion descirbe
# count Anzahl Zellen
# mean Medianwert
# 
apcs["euro"].describe()
# Out:
# count      61.000000
# mean     1419.608033
# std       456.811349
# min       219.840000
# 25%      1178.420000
# 50%      1410.070000
# 75%      1800.000000
# max      2000.000000
# Name: euro, dtype: float64

# %%
# Abfrage auf ganze Serie, ob Zellenwert grössergleich 2000 ist, gibt Booleanischen Wert zurück.
apcs["euro"] >= 2000
# Out:
# 0      True
# 1     False
# 2      True
# 3      True
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60     True
# Name: euro, Length: 61, dtype: bool

# %%
# Neuer Dataframe erstellen mit allen APC's über 2000
apcs_2000_and_above = apcs[apcs["euro"] >= 2000]

# %%
apcs_2000_and_above[["euro", "publisher", "doi"]]
# Out:
#       euro                         publisher                            doi
# 0   2000.0                   Springer Nature          10.1038/npjqi.2015.10
# 2   2000.0                   Springer Nature             10.1038/ncomms9498
# 3   2000.0  Public Library of Science (PLoS)   10.1371/journal.ppat.1005246
# 12  2000.0                Frontiers Media SA       10.3389/fpsyg.2015.01675
# 15  2000.0  Public Library of Science (PLoS)   10.1371/journal.ppat.1004781
# 23  2000.0                     Schweizerbart         10.1127/metz/2015/0641
# 28  2000.0                Frontiers Media SA       10.3389/fnhum.2015.00551
# 29  2000.0                   Springer Nature             10.1038/ncomms8606
# 32  2000.0                   Springer Nature      10.1186/s12918-015-0183-x
# 45  2000.0  Public Library of Science (PLoS)   10.1371/journal.pcbi.1004200
# 60  2000.0    Hindawi Publishing Corporation            10.1155/2015/569512

# %%
# Histrogramm erstellen
apcs["euro"].hist(bins=10, color="green")
# Out:
# <AxesSubplot:>

# %%
apcs["publisher"]
# Out:
# 0                      Springer Nature
# 1      American Physical Society (APS)
# 2                      Springer Nature
# 3     Public Library of Science (PLoS)
# 4                      Springer Nature
#                     ...
# 56                     Springer Nature
# 57                  Frontiers Media SA
# 58                  Frontiers Media SA
# 59                     Springer Nature
# 60      Hindawi Publishing Corporation
# Name: publisher, Length: 61, dtype: object

# %%
apcs["publisher"].describe()
# Out:
# count                     61
# unique                    15
# top       Frontiers Media SA
# freq                      16
# Name: publisher, dtype: object

# %%
apcs["publisher"].max()
# Out:
# 'The Korean Society of Veterinary Science (KAMJE)'

# %%
# Filtern nach Publisher contains Keyword Springer
apcs[apcs["publisher"].str.contains ("Springer")]
# Out:
#    institution  period     euro                        doi  is_hybrid  \
# 0    FU Berlin    2015  2000.00      10.1038/npjqi.2015.10      False
# 2    FU Berlin    2015  2000.00         10.1038/ncomms9498      False
# 4    FU Berlin    2015  1805.00  10.1186/s13099-015-0075-z      False
# 13   FU Berlin    2015  1165.00          10.1038/srep11598      False
# 14   FU Berlin    2015  1386.35          10.1038/srep12681      False
# 24   FU Berlin    2015  1249.50  10.1186/s13570-015-0035-8      False
# 25   FU Berlin    2015  1625.00  10.1186/s13071-015-0924-0      False
# 26   FU Berlin    2015  1800.00  10.1186/s12862-015-0390-5      False
# 29   FU Berlin    2015  2000.00         10.1038/ncomms8606      False
# 32   FU Berlin    2015  2000.00  10.1186/s12918-015-0183-x      False
# 54   FU Berlin    2015  1969.45  10.1186/s12917-015-0351-7      False
# 56   FU Berlin    2015  1731.45  10.1186/s13015-014-0028-y      False
# ...
